# %% [markdown]
# # Разведочный анализ данных для набора данных: Netflix

# %% [markdown]
# ## Задание
#
# Вам предлагается выполнить разведочный анализ данных и описать полученные результаты
#
# Описание набора данных: https://www.kaggle.com/datasets/narayan63/netflix-popular-movies-dataset
#
# Ссылка на набор данных для использования в блокноте: https://raw.githubusercontent.com/yakushinav/journ/refs/heads/main/datasets/netflix.csv

# %% [markdown]
# #### 1. Подключение библиотек

# %%
# Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# #### 2. Чтение набора данных

# %%
# Ваш код здесь
df = pd.read_csv('https://raw.githubusercontent.com/yakushinav/journ/refs/heads/main/datasets/netflix.csv')

# %% [markdown]
# #### 3. Первые 5 строк набора данных

# %%
# Ваш код здесь
df.head(5)
# Out:
#                     title        year certificate  duration  \
# 0               Cobra Kai      2018.0       TV-14      30.0
# 1               The Crown      2016.0       TV-MA      58.0
# 2        Better Call Saul  20152022.0       TV-MA      46.0
# 3           Devil in Ohio      2022.0       TV-MA     356.0
# 4  Cyberpunk: Edgerunners      2022.0       TV-MA      24.0
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %% [markdown]
# #### 4. Последние 7 строк набора данных

# %%
# Ваш код здесь
df.tail(7)
# Out:
#                       title        year certificate  duration  \
# 9950  American Horror Story      2011.0       TV-MA      60.0
# 9951           Breaking Bad  20082013.0       TV-MA      49.0
# 9952         The Imperfects      2022.0       TV-MA      45.0
# 9953       The Walking Dead  20102022.0       TV-MA      44.0
# 9954              The Crown      2016.0       TV-MA      58.0
# 9955           Supernatural  20052020.0       TV-14      44.0
# 9956          Devil in Ohio      2022.0       TV-MA     356.0
#
#                           genre  rating  \
# 9950      Drama, Horror, Sci-Fi     8.0
# 9951     Crime, Drama, Thriller     9.5
# 9952   Action, Adventure, Drama     6.3
# 9953    Drama, Horror, Thriller     8.1
# 9954  Biography, Drama, History     8.7
# 9955     Drama, Fantasy, Horror     8.4
# 9956     Drama, Horror, Mystery     5.9
#
#                                             description  \
# 9950  An anthology series centering on different cha...
# ...

# %% [markdown]
# #### 5. Поля набора данных

# %%
# Ваш код здесь
df.columns
# Out:
# Index(['title', 'year', 'certificate', 'duration', 'genre', 'rating',
#        'description', 'stars', 'votes'],
#       dtype='object')

# %% [markdown]
# #### 6. Размер набора данных (количество полей и строк)

# %%
# Ваш код здесь
df.shape
# Out:
# (9957, 9)

# %% [markdown]
# #### 7. Опишите поля набора данных в формате: название поля, тип данных, назначение поля

# %% [markdown]
# **title** категориальный, содержит название фильма
#
# **year** числовой, обозначает год выпуска фильма.
#
# **certificate** категориальный, указывает возрастное ограничение фильма.
#
# **duration** числовой, показывает продолжительность фильма.
#
# **genre** категориальный, определяет жанр фильма.
#
# **rating** числовой, представляет рейтинг фильма.
#
# **description** категориальный, содержит краткое описание сюжета фильма.
#
# **stars** категориальный, перечисляет главных актеров фильма.
#
# **votes** числовой, показывает количество голосов зрителей за фильм.

# %% [markdown]
# #### 8. Информация о наборе данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        9957 non-null   object
#  1   year         9326 non-null   float64
#  2   certificate  6504 non-null   object
#  3   duration     7921 non-null   float64
#  4   genre        9884 non-null   object
#  5   rating       8784 non-null   float64
#  6   description  9957 non-null   object
#  7   stars        9957 non-null   object
#  8   votes        8784 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 700.2+ KB

# %% [markdown]
# #### 9. Описательная статистика для числовых полей

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                        title        year certificate  duration  \
# 0                  Cobra Kai      2018.0       TV-14      30.0
# 1                  The Crown      2016.0       TV-MA      58.0
# 2           Better Call Saul  20152022.0       TV-MA      46.0
# 3              Devil in Ohio      2022.0       TV-MA     356.0
# 4     Cyberpunk: Edgerunners      2022.0       TV-MA      24.0
# ...                      ...         ...         ...       ...
# 9952          The Imperfects      2022.0       TV-MA      45.0
# 9953        The Walking Dead  20102022.0       TV-MA      44.0
# 9954               The Crown      2016.0       TV-MA      58.0
# 9955            Supernatural  20052020.0       TV-14      44.0
# 9956           Devil in Ohio      2022.0       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# ...

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of                        title        year certificate  duration  \
# 0                  Cobra Kai      2018.0       TV-14      30.0
# 1                  The Crown      2016.0       TV-MA      58.0
# 2           Better Call Saul  20152022.0       TV-MA      46.0
# 3              Devil in Ohio      2022.0       TV-MA     356.0
# 4     Cyberpunk: Edgerunners      2022.0       TV-MA      24.0
# ...                      ...         ...         ...       ...
# 9952          The Imperfects      2022.0       TV-MA      45.0
# 9953        The Walking Dead  20102022.0       TV-MA      44.0
# 9954               The Crown      2016.0       TV-MA      58.0
# 9955            Supernatural  20052020.0       TV-14      44.0
# 9956           Devil in Ohio      2022.0       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# ...

# %% [markdown]
# #### 10. Описательная статистика для категориальных полей

# %%
df.describe(include=['object', 'bool'])
# Out:
#            title certificate   genre description stars
# count       9957        6504    9884        9957  9957
# unique      7912          20     569        9433  8615
# top     Top Gear       TV-MA  Comedy  Add a Plot    []
# freq          92        2520     859         434   403

# %%
df['title'].value_counts() #тоже самое можно проделать с другими категориальными полями
# Out:
# title
# Top Gear                                    92
# Bleach                                      67
# The Queen and the Conqueror                 61
# Avatar: The Last Airbender                  54
# Johnny Test                                 34
#                                             ..
# Invader ZIM: Enter the Florpus               1
# The Numbers Station                          1
# Death to 2020                                1
# Pokémon: Mewtwo Strikes Back - Evolution     1
# Results                                      1
# Name: count, Length: 7912, dtype: int64

# %% [markdown]
# #### 11. Проверка наличия пропусков в данных

# %%
# Ваш код здесь
df.isnull().sum()
# Out:
# title             0
# year            631
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %%
df.drop(['certificate'], axis=1, inplace=True)

# %%
df["duration"].sort_values()
# Out:
# 6287    1.0
# 6119    1.0
# 6282    1.0
# 6985    1.0
# 7296    1.0
#        ...
# 9900    NaN
# 9910    NaN
# 9913    NaN
# 9920    NaN
# 9936    NaN
# Name: duration, Length: 9957, dtype: float64

# %%
df.loc[9900]
# Out:
# title                                                  Chocolate
# year                                                  20192020.0
# certificate                                                  NaN
# duration                                                     NaN
# genre                                             Drama, Romance
# rating                                                       8.8
# description    Kang chooses what's most important to him. Cha...
# stars          ['Lee Hyeong-min', '| ', '    Stars:', 'Ha Ji-...
# votes                                                       12.0
# Name: 9900, dtype: object

# %% [markdown]
# #### 12. Если вы обнаружили пропуски в данных, то заполните их на основе среднего или медианы или моды

# %%
df['duration'] = df['duration'].fillna(df['duration'].median())
df['rating'] = df['rating'].fillna(df['rating'].median())

# %%
df.isnull().sum()
# Out:
# title             0
# year            631
# duration          0
# genre            73
# rating            0
# description       0
# stars             0
# votes          9957
# dtype: int64

# %%
df['votes'] = df['votes'].fillna(0, inplace=True) #хотела попробовать заменить все пропуски в votes на ноль, но походу не вышло, потому что он заменил все значения на ноль...
# Out:
# <ipython-input-19-0b7a66f2841b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['votes'] = df['votes'].fillna(0, inplace=True)

# %% [markdown]
# #### 13. Фильтрация. Выберите все строки таблицы, для которых значение поля rating больше 5.0

# %%
# Ваш код здесь
df[df['rating'] > 5.0]
# Out:
#                        title        year certificate  duration  \
# 0                  Cobra Kai      2018.0       TV-14      30.0
# 1                  The Crown      2016.0       TV-MA      58.0
# 2           Better Call Saul  20152022.0       TV-MA      46.0
# 3              Devil in Ohio      2022.0       TV-MA     356.0
# 4     Cyberpunk: Edgerunners      2022.0       TV-MA      24.0
# ...                      ...         ...         ...       ...
# 9952          The Imperfects      2022.0       TV-MA      45.0
# 9953        The Walking Dead  20102022.0       TV-MA      44.0
# 9954               The Crown      2016.0       TV-MA      58.0
# 9955            Supernatural  20052020.0       TV-14      44.0
# 9956           Devil in Ohio      2022.0       TV-MA     356.0
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %% [markdown]
# #### 14. Фильтрация. Выберите все строки таблицы, для которых значение поля description равно Add a Plot

# %%
# Ваш код
df[df['description'] == 'Add a Plot']
# Out:
#                                  title    year certificate  duration  \
# 2207                    Back in Action     NaN         NaN       NaN
# 3259                     Never Give Up  2022.0         NaN       NaN
# 3286         Octonauts: Above & Beyond  2021.0        TV-Y       NaN
# 3338  Untitled We Can Be Heroes Sequel  2024.0         NaN       NaN
# 3744                  The Blue Whisper  2022.0         NaN       NaN
# ...                                ...     ...         ...       ...
# 9876                    Astronomy Club  2019.0       TV-MA       NaN
# 9877                    Astronomy Club  2019.0       TV-MA       NaN
# 9878                    Astronomy Club  2019.0       TV-MA       NaN
# 9879                    Astronomy Club  2019.0       TV-MA       NaN
# 9882                   Lugar de Mulher  2019.0         NaN      16.0
#
#                           genre  rating description  \
# 2207             Action, Comedy     NaN  Add a Plot
# ...

# %% [markdown]
# #### 15. Фильтрация. Выберите все строки таблицы, для которых значение поля title равно Top Gear и значение поля stars равно []

# %%
# Ваш код здесь
df[(df['title'] == 'Top Gear') & (df['stars'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [title, year, certificate, duration, genre, rating, description, stars, votes]
# Index: []

# %% [markdown]
# #### 16. Получите все уникальные значения поля  stars и подсчитайте частоту появления каждого их них

# %%
# Ваш код здесь
df['stars'].unique()
# Out:
# array(["['Ralph Macchio, ', 'William Zabka, ', 'Courtney Henggeler, ', 'Xolo Maridueña']",
#        "['Claire Foy, ', 'Olivia Colman, ', 'Imelda Staunton, ', 'Matt Smith']",
#        "['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan Banks, ', 'Patrick Fabian']",
#        ...,
#        "['Mira Nair', '| ', '    Stars:', 'Tanya Maniktala, ', 'Danesh Razvi, ', 'Boloram Das, ', 'Mahira Kakkar']",
#        "['John Hyams', '| ', '    Stars:', 'Jaime King, ', 'Justin Chu Cary, ', 'Christine Lee, ', 'Zoe Marlett']",
#        "['Sheldon Epps', '| ', '    Stars:', 'Mike Epps, ', 'Kim Fields, ', 'Diamond Lyons, ', 'Wanda Sykes']"],
#       dtype=object)

# %% [markdown]
# #### 17. Выполните группировку набора данных одновременно по полям stars и title. Добавьте подсчет минимума, максимума и медианы по каждой группе.

# %%
# Ваш код
df.groupby(['stars', 'title']).agg({'rating': ['min', 'max', 'median']})
# Out:
#                                                                                       rating  \
#                                                                                          min
# stars                                              title
# ["Alessandro D'Alatri", '| ', '    Stars:', 'Ma... La legge del numero uno               6.1
# ["Alex O'Loughlin, ", 'Scott Caan, ', 'Taylor W... Hawaii Five-0                         7.4
# ["Bill D'Elia", '| ', '    Star:', "Chris D'Elia"] Chris D'Elia: Incorrigible            6.4
#                                                    Chris D'Elia: Man on Fire             6.5
# ["Chris O'Donnell, ", 'LL Cool J, ', 'Daniela R... NCIS: Los Angeles                     6.7
# ...                                                                                      ...
# []                                                 Word Party: Happy Birthday to You!    3.7
# ...

# %% [markdown]
# #### 18. Постройте поле корреляции (тепловая карта) для числовых полей

# %%
# Ваш код здесь
numerical_df = df.select_dtypes(include=['number'])
numerical_df.corr()
# Out:
#               year  duration    rating     votes
# year      1.000000 -0.304743  0.316391  0.047665
# duration -0.304743  1.000000 -0.166247  0.107793
# rating    0.316391 -0.166247  1.000000  0.142622
# votes     0.047665  0.107793  0.142622  1.000000

# %% [markdown]
# **Вывод:**
#
# Зависимости между переменными слабые, так как все коэффициенты корреляции находятся далеко от +-1.

# %% [markdown]
# #### 19. Постройте гистограмму по полю year

# %%
# Ваш код здесь
import matplotlib.pyplot as plt
df['year'].hist()
plt.show()

# %% [markdown]
# **Вывод**
#
# Большинство значений сосредоточено в диапазоне около 0, а небольшая часть данных находится в районе 2.00. Возможно, это указывает на сильную асимметрию распределения данных.

# %% [markdown]
# #### 20. Постройте точечную диаграмму для полей votes и year

# %%
# Ваш код здесь
df.plot.scatter(x='votes', y='year')
plt.show()

# %% [markdown]
#  **Вывод**
#
#  Большинство данных сосредоточено в двух кластерах: один около нулевого значения по оси "year", а другой — около 20 миллионов. Это может указывать на некорректное масштабирование или ошибки в данных.

# %% [markdown]
# #### 21. Постройте диаграмму ящик с усами поля votes

# %%
# Ваш код здесь. Также напишите о наличии выбросов в этом поле
df['votes'].plot.box()
plt.show()

# %% [markdown]
# **Вывод**
#
#  Большинство значений сосредоточено около нуля, а также присутствуют выбросы — отдельные значения значительно превышают основную массу данных, достигая более 1 миллиона голосов.

# %% [markdown]
# #### 22. Постройте матрицу диаграммы рассеяния

# %%
# Визуализация данных
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Ваш код здесь
numeric_columns = df.select_dtypes(include=['number']).columns
sns.pairplot(df[numeric_columns], diag_kind='kde', height=2)
plt.show()

# %% [markdown]
# #### 23. Преобразуйте все категориальные поля в числовые с помощью LabelEncoder

# %%
# Ваш код здесь
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['title'] = le.fit_transform(df['title'])
df['description'] = le.fit_transform(df['description'])

# %% [markdown]
# #### 24. Сделайте вывод о проделанной работе и особенностях набора данных

# %% [markdown]
# На самом деле, не всегда было просто анализировать полученные графики или получались выводы, которые не представляли интересных выводов.
# Но у датасета хороший потенциал, например, данные могут быть использованы для анализа тенденций в производстве контента Netflix, предпочтений зрителей и влияния различных факторов на успех шоу.
